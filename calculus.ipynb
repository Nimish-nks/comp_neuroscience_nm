# %% [markdown]
# # Calculus

# %% [markdown]
# Derivative captures how sensitive a function is to slight changes in input.
# Integration is finding out the function whose derivative is that you are integrating

# %% [markdown]
# f'=a*f , then f is eigenfunction for derivative operator
# Integral(f) = a * f, then f is eigenfunction for integral operator

# %%
a = 5

# %%
import sympy as sp

# %%
f,t = sp.symbols('f,t')

f=1/(1+sp.exp(-(t-5)))
diff_f=sp.diff(f)
print(diff_f)
# Out:
# exp(5 - t)/(exp(5 - t) + 1)**2

# %% [markdown]
# When you inject current in neuron, it's firing rate changes.  We can simulate it using Sigmoid function. The slope of this neuron input output transfer function is called gain
